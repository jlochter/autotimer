# %%
# Install autotimer from GitHub
# !pip install -q git+https://github.com/jlochter/autotimer.git

# --- Configuration ---
GOOGLE_API_KEY = ""  # Paste your Gemini API key here
GDRIVE_PATH = "/content/drive/MyDrive/Raws/"
CHUNK_LENGTH = 30     # Transcription window size in seconds

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Run the pipeline
import autotimer
autotimer.run(
    api_key=GOOGLE_API_KEY, 
    gdrive_path=GDRIVE_PATH, 
    chunk_length=CHUNK_LENGTH
)

# Destroy runtime
from google.colab import runtime
runtime.unassign()
